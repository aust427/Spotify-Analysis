# %%
import sys
import spotipy
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import interpolate

# %%
from spotipy.oauth2 import SpotifyClientCredentials
client_credentials_manager = SpotifyClientCredentials(client_id='6fccc6dad8504b2292cc1f6cddc422ba', client_secret='b337b568dd5b42ab80a1318e6a75819d')

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
def getAudioFeatures(playlist):
    df = pd.DataFrame(columns=['name', 'danceability', 'energy', 'key', 'loudness',
                           'speechiness', 'acousticness', 'instrumentalness',
                           'liveness', 'valence', 'tempo', 'duration_ms'])
    
    tracks = playlist['items']

    while playlist['next']:
        playlist = sp.next(playlist)
        tracks.extend(playlist['items'])

    for i in range(0, len(tracks)):
        song_features = sp.audio_features(tracks[i]['track']['id'])[0]
        song_features['name'] = tracks[i]['track']['name']

        for key in df.keys():
            df.loc[i,key] = song_features[key]

    df['duration_min'] = df['duration_ms'] / 1000 / 60
    df = df.drop(columns=['duration_ms'])

    return df

# %%
user = "1248025501"

# %%
rand_playlist_id = "3gt9k1D9Hk4ABCIHfQhZL8"
rand_df = getAudioFeatures(sp.user_playlist_tracks(user, rand_playlist_id))

# %%
like_playlist_id = "6OADABzWPd8HgdVFli0NXB"
like_df = getAudioFeatures(sp.user_playlist_tracks(user, like_playlist_id))

# %%
dislike_playlist_id = "1AZxiL7LrFGT3PGoecDdpB"
dislike_df = getAudioFeatures(sp.user_playlist_tracks(user, dislike_playlist_id))

# %%
dislike_df['like'] = 0
like_df['like'] = 1

# %%
def plotter(key, bins):
    bin_w = (bins[1] - bins[0]) / 2
    
    mean_l = sum(like_df[key]) / len(like_df[key])
    mean_d = sum(dislike_df[key]) / len(dislike_df[key])
    
    weights_l = np.ones_like(list(like_df[key]))/float(len(like_df[key]))
    weights_d = np.ones_like(list(dislike_df[key]))/float(len(dislike_df[key]))
    
    plt.figure(figsize=(8,8))
    plt.axvline(x=mean_l, color = 'royalblue', ls = '--')
    plt.axvline(x=mean_d, color = 'darkorange', ls = '--')

    hist_l = plt.hist(list(like_df[key]), bins, alpha=0.15, label='like', color = 'royalblue', weights = weights_l)
    hist_d = plt.hist(list(dislike_df[key]), bins, alpha=0.15, label='dislike', color = 'darkorange', weights = weights_d)
    
    xnew = np.arange(bins[0], bins[-2], 0.0001)

    f = interpolate.interp1d(bins[0:len(bins) - 1] + bin_w, hist_l[0], bounds_error=False, kind ='quadratic')
    ynew = f(xnew)
    plt.plot(xnew, ynew, color = 'royalblue')

    f = interpolate.interp1d(bins[0:len(bins) - 1] + bin_w, hist_d[0], bounds_error=False, kind ='quadratic')
    ynew = f(xnew)
    plt.plot(xnew, ynew, color = 'darkorange')

    plt.ylim(ymin = 0)
    plt.legend(loc='upper right')
    plt.title(key)
    plt.show()

# %%
plotter('tempo', np.linspace(50, 230, 20))

# %%
plotter('energy', np.linspace(0, 1, 20))

# %%
plotter('danceability', np.linspace(0, 1, 20))

# %%
plotter('key', np.linspace(0, 11, 12))

# %%
plotter('acousticness', np.linspace(0, 1, 20))

# %%
plotter('instrumentalness', np.linspace(0, 1, 20))

# %%
plotter('liveness', np.linspace(0, 1, 20))

# %%
plotter('loudness', np.linspace(-30, 0, 30))

# %%
plotter('speechiness', np.linspace(0, 1, 20))

# %%
plotter('valence', np.linspace(0, 1, 20))

# %%
plotter('duration_min', np.linspace(1, 10, 20))

# %%
features = ['duration_min', 'valence', 'speechiness',
           'loudness', 'instrumentalness', 'liveness',
           'acousticness', 'danceability', 'energy',
           'tempo']

# %%
plt.figure(figsize = (20, 20))
gs1 = gridspec.GridSpec(len(features), len(features))
gs1.update(wspace=0, hspace=0) 

for i in range(0, len(features)):
    f_y = features[i]
    for j in range(0, len(features)):
        ax = plt.subplot(gs1[i, j])
        f_x = features[j]
        
        if (i < len(features) - 1): 
            ax.tick_params( axis='x', labelbottom = False, labelleft = False, direction = 'in') 
        if (j > 0):
            ax.tick_params( axis='y', labelbottom = False, labelleft = False, direction = 'in') 

        if j == i:
            ax.annotate(f_x, (0.5, 0.5), xycoords='axes fraction', ha='center', va='center')
            continue 
         
        if j > i:
            ax.axis('off')
            continue
            
        ax.scatter(like_df[f_x], like_df[f_y], color = 'royalblue', s = 8)
        ax.scatter(dislike_df[f_x], dislike_df[f_y], color = 'darkorange', s = 8)

# %% [markdown]
# # Machine Learning

# %%
class_dict = {'knn': {'acc': 0, 'classifier': 0, 'matrix': 0},
              'svm-linear': {'acc': 0, 'classifier': 0, 'matrix': 0}, 
              'svm-rbf': {'acc': 0, 'classifier': 0, 'matrix': 0},
              'random-forest': {'acc': 0, 'classifier': 0, 'matrix': 0}
             }

# %%
import sklearn
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
# Out:
# C:\Users\austr\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\austr\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
idx = np.random.choice(like_df.shape[0], dislike_df.shape[0], replace = False)

songs_df = pd.concat([like_df.iloc[idx], dislike_df])
X = songs_df.iloc[:,:-1]
X = X.drop(columns=['name'])
Y = songs_df['like']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25)

# %% [markdown]
# ## k-Nearest Neighbors (kNN)

# %% [markdown]
# Evalues k neighbors before assigning a class, usually $k =(n_{row}) ^2$.

# %%
#plt.plot(np.arange(1, len(knn_acc) + 1, 1), knn_acc)

# %%
classifier = KNeighborsClassifier(n_neighbors = int(np.floor(X_train.shape[0]**(0.5))))
classifier.fit(X_train, y_train)
p = classifier.predict(X_test)
mat = sklearn.metrics.confusion_matrix(y_true = y_test, y_pred = p)
class_dict['knn']['matrix'] = mat
class_dict['knn']['acc'] = (mat[0,0] + mat[1, 1]) / sum(sum(mat))
class_dict['knn']['classifier'] = classifier
print(class_dict['knn']['acc'])
# Out:
# 0.41025641025641024

# %% [markdown]
# ## Support Vector Machine (SVM)

# %% [markdown]
# SVM draws a hyperplane between points to separate them into classes.

# %%
kernels = ["linear", "rbf"]
# "poly",
for i in range(0, 2):
    classifier = SVC(kernel=kernels[i]) 
    classifier.fit(X_train, y_train)
    p = classifier.predict(X_test)
    mat = sklearn.metrics.confusion_matrix(y_true = y_test, y_pred = p)
    class_dict['svm-'+kernels[i]]['matrix'] = mat
    class_dict['svm-'+kernels[i]]['acc'] = (mat[0,0] + mat[1, 1]) / sum(sum(mat))
    class_dict['svm-'+kernels[i]]['classifier'] = classifier
    print(kernels[i], class_dict['svm-'+kernels[i]]['acc'])
# Out:
# linear 0.6666666666666666
# rbf 0.5641025641025641

# %% [markdown]
# ## Random Forest (RF)

# %% [markdown]
# Decision trees, but a lot of them.

# %%
classifier = RandomForestClassifier(n_estimators=100)
classifier.fit(X_train, y_train)
p = classifier.predict(X_test)
mat = sklearn.metrics.confusion_matrix(y_true = y_test, y_pred = p)
class_dict['random-forest']['matrix'] = mat
class_dict['random-forest']['acc'] = (mat[0,0] + mat[1, 1]) / sum(sum(mat))
class_dict['random-forest']['classifier'] = classifier
print(class_dict['random-forest']['acc'])
# Out:
# 0.6923076923076923

# %% [markdown]
# ## Logistic Regression (LogReg)

# %% [markdown]
# ## Choosing best classifier

# %%
max_acc = 0 
max_key = ''

for key in class_dict:
    print(key, class_dict[key]['acc'])
    if class_dict[key]['acc'] > max_acc:
        max_key = key
        max_acc = class_dict[key]['acc']
# Out:
# knn 0.41025641025641024
# svm-linear 0.6666666666666666
# svm-rbf 0.5641025641025641
# random-forest 0.6923076923076923

# %%
classifier = class_dict[max_key]['classifier']
print(pd.DataFrame(class_dict[max_key]['matrix'], columns=['pred. 0', 'pred. 1'], index=['act. 0', 'act. 1']))
# Out:
#         pred. 0  pred. 1
# act. 0       13        2
# act. 1       10       14

# %% [markdown]
# # Predictive Datasets

# %%
jp_playlist_id = "1TEgN1E2KrhTgrq6zc9o3k"
jp_df = getAudioFeatures(sp.user_playlist_tracks(user, jp_playlist_id))

good_inst_playlist_id = "2CGrG9oXvsUYZ0sav4nMTE"
good_inst_df = getAudioFeatures(sp.user_playlist_tracks(user, good_inst_playlist_id))

rand_playlist_id = "3gt9k1D9Hk4ABCIHfQhZL8"
rand_df = getAudioFeatures(sp.user_playlist_tracks(user, rand_playlist_id))

# %%
def predictor(df, classifier, flag):
    names = df['name']
    df = df.drop(columns=['name'])
    p = classifier.predict(df)
    if (not flag):
        print("accuracy: ", sum(p) / len(p))
    print("labeled dislike:")
    print(names[p == 0])
    if (flag):
        print("labeled like:")
        print(names[p == 1])

# %%
predictor(jp_df, classifier, False)
# Out:
# accuracy:  0.8732394366197183
# labeled dislike:
# 1                     Passion - after the battle
# 3                                 FINAL DISTANCE
# 8                                       Kataomoi
# 35                                Days - Re Ver.
# 39                                         Stars
# 47                                 The Beginning
# 56                            Sakura Iro No Yume
# 57                                       Fluquor
# 58         I Race the Dawn (feat. Michiyo Honda)
# 65                                         Orion
# 70                                       Miracle
# 74                                        Crowds
# 85                                     Stray Cat
# 87                     Euterpe - 2017 Remastered
# 104                                   THIS IS ME
# 109    Abnormalize (Best of Tornado Remastering)
# 119              Face My Fears - English Version
# 131                                        ファイター
# Name: name, dtype: object

# %%
predictor(good_inst_df, classifier, False)
# Out:
# accuracy:  0.6129032258064516
# labeled dislike:
# 7                                            Stars
# 10                                   American Love
# 11    Details in the Fabric (feat. James Morrison)
# 12                                        Superman
# 16                             Death of a Bachelor
# 19                                         Fluquor
# 21                        Lovely Day (Bonus Track)
# 22                                     Life Itself
# 23                                       100 Years
# 26                                在你死後才想起曾經答應陪你去散步
# 28                                  The Golden Age
# 30                     Love Like You (End Credits)
# Name: name, dtype: object

# %%
predictor(rand_df, classifier, True)
# Out:
# labeled dislike:
# 1                                        Straightjacket
# 7                                          Great Divide
# 12                                        I'll Be There
# 13                                            Last Leaf
# 14                                                 Weak
# 17                                           All I Need
# 19                             SLOW DANCING IN THE DARK
# 24                                              Ladders
# 25                                            Deadcrush
# 27                                             Stay Flo
# 29                                                Fangs
# 30           Martyr of the Free Word - Acoustic Version
# 33                                             无羁 - 器乐版
# 38                         Chrono Cross -Scars of Time-
# 42                                      Motion Sickness
# 45                                              Mean It
# ...
